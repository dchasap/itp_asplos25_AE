# %% [markdown]
# # Hello Jupyter Notebook (Minimal Example)
#
# This notebook shows:
# - how code cells work
# - how variables persist
# - how execution order matters
#
# ---
#
# ## Cell 1 — Print Hello World
#
# ```python
# print("Hello, world!")
# ```
#
# ---
#
# ## Cell 2 — Variables
#
# ```python
# x = 10
# y = 20
# print("Variables created")
# ```
#
# ---
#
# ## Cell 3 — Reuse Variables
#
# ```python
# print("Sum =", x + y)
# ```
#
# ---
#
# ## Cell 4 — Loop Example
#
# ```python
# for i in range(5):
#     print("i =", i)
# ```
#
# ---
#
# ## Cell 5 — Function Example
#
# ```python
# def greet(name):
#     return "Hello " + name
# ```
#
# ---
#
# ## Cell 6 — Use Function
#
# ```python
# print(greet("Alice"))
# print(greet("Bob"))
# ```
#
# ---
#
# ## Cell 7 — Delay Example (simulates long job)
#
# ```python
# import time
#
# print("Starting...")
# time.sleep(2)
# print("Finished after 2 seconds")
# ```
#
# ---
#
# ## Key Idea
#
# - Each cell runs independently
# - But all cells share the same memory (kernel)
# - Order of execution matters
# ```
