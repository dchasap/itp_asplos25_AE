# %%
./scripts/manage_experiment.py --config exp_conf/pb_sibling_pf_eval.ini --build --run

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/pb_sibling_pf_eval.ini --parse
# Out:
# /home/bscuser/synched_mnt/VMem
# Preprocessing configuration file...
# ['rsync', '-avz', '--no-checksum', '--ignore-errors', '--include=*/', '--include=*.out', '--exclude=*', 'bsc018186@transfer1.bsc.es:/gpfs/scratch/bsc18/bsc018186/VMem/data/pb_sibling_pf_eval/BASELINE', './data/pb_sibling_pf_eval']
# /home/bsc/bsc018186/.bashrc: line 2: module: command not found
# /home/bsc/bsc018186/.bashrc: line 3: module: command not found
# /home/bsc/bsc018186/.bashrc: line 4: module: command not found
# /home/bsc/bsc018186/.bashrc: line 5: module: command not found
# receiving incremental file list
# created directory ./data/pb_sibling_pf_eval
# BASELINE/
# BASELINE/selected_qualcomm_srv_ap_0_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_20_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_40_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_60_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_80_BASELINE_run.out
# BASELINE/srv100_ap_BASELINE_run.out
# ...

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/pb_sibling_pf_eval.ini --plot
from IPython.display import Image, display
display(Image("./figures/pb_sibling_pf_eval/pb_sibling_pf_eval_ipc_selected_qualcomm_srv_ap.png", 
width=600, height=600))
# Out:
# /home/bscuser/synched_mnt/VMem
# Preprocessing configuration file...
# ['BASELINE', 'pb-l1d_sibling_pf', 'pb-l2c_sibling_pf']
# Plotting pb_sibling_pf_eval for selected_qualcomm_srv_ap
# ['BASELINE', 'pb-l1d_sibling_pf', 'pb-l2c_sibling_pf']
#                  tag  IPC_IMPROVEMENT
# 0  pb-l1d_sibling_pf         0.164908
# 1  pb-l2c_sibling_pf         0.057055
# pb-l1d_sibling_pf:0.4425084624626959
# pb-l2c_sibling_pf:0.17093043466254937
#   benchmarks                tag      mean
# 0       mean  pb-l1d_sibling_pf  0.442508
# 1       mean  pb-l2c_sibling_pf  0.170930
#   benchmarks                tag      mean
# 0       mean  pb-l1d_sibling_pf  0.442508
# 1       mean  pb-l2c_sibling_pf  0.170930
# ./figures/pb_sibling_pf_eval/pb_sibling_pf_eval_ipc_selected_qualcomm_srv_ap.png
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Plotting completed successfully
