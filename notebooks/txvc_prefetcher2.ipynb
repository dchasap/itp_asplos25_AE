# %%
./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch.ini --build --run

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch.ini --parse
# Out:
# /home/bscuser/synched_mnt/VMem
# Preprocessing configuration file...
# ['rsync', '-av', '--include=*/', '--include=*.out', '--exclude=*', 'bsc018186@transfer1.bsc.es:/gpfs/scratch/bsc18/bsc018186/VMem/data/txvc_prefetch_eval/BASELINE', './data/txvc_prefetch_eval']
# /home/bsc/bsc018186/.bashrc: line 2: module: command not found
# /home/bsc/bsc018186/.bashrc: line 3: module: command not found
# /home/bsc/bsc018186/.bashrc: line 4: module: command not found
# /home/bsc/bsc018186/.bashrc: line 5: module: command not found
# receiving incremental file list
# BASELINE/selected_qualcomm_srv_ap_0_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_20_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_40_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_60_BASELINE_run.out
# BASELINE/selected_qualcomm_srv_ap_80_BASELINE_run.out
# BASELINE/srv100_ap_BASELINE_run.out
# BASELINE/srv103_ap_BASELINE_run.out
# BASELINE/srv111_ap_BASELINE_run.out
# BASELINE/srv120_ap_BASELINE_run.out
# ...

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch.ini --plot --override "PLOTTING.file_type=pdf"
from IPython.display import Image, display
display(Image("./figures/txvc_prefetch_eval/txvc_prefetch_eval_ipc_selected_qualcomm_srv_ap.png", 
width=600, height=600))
# Out:
# /home/bscuser/synched_mnt/VMem
# Override applied: PLOTTING.file_type='pdf'
# Preprocessing configuration file...
# ['BASELINE', 'txvc_l1d_child_ideal_pf', 'txvc_l1d_freq_filter', 'txvc_l1d_child_ideal_pf+freq_filter', 'txvc_l2c_child_ideal_pf', 'txvc_l2c_freq_filter', 'txvc_l2c_child_ideal_pf+freq_filter']
# Plotting txvc_prefetch_eval for selected_qualcomm_srv_ap
# ['BASELINE', 'txvc_l1d_child_ideal_pf', 'txvc_l1d_freq_filter', 'txvc_l1d_child_ideal_pf+freq_filter', 'txvc_l2c_child_ideal_pf', 'txvc_l2c_freq_filter', 'txvc_l2c_child_ideal_pf+freq_filter']
#                                    tag  IPC_IMPROVEMENT
# 2                 txvc_l1d_freq_filter         3.138397
# 1  txvc_l1d_child_ideal_pf+freq_filter         2.873800
# 5                 txvc_l2c_freq_filter         2.599276
# 4  txvc_l2c_child_ideal_pf+freq_filter         2.135519
# 3              txvc_l2c_child_ideal_pf         1.564550
# 0              txvc_l1d_child_ideal_pf         1.523725
# ...

# %%
./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch.ini --build --run --override "EXPERIMENT.simulations = %(simulations_base)s, %(simulations_txvc_unlimit_l1d)s, %(simulations_txvc_unlimit_l2c)s"

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch.ini --parse --override "EXPERIMENT.simulations = %(simulations_base)s, %(simulations_txvc_unlimit_l1d)s, %(simulations_txvc_unlimit_l2c)s"
# Out:
# /home/bscuser/synched_mnt/VMem
# Override applied: EXPERIMENT.simulations='%(simulations_base)s, %(simulations_txvc_unlimit_l1d)s, %(simulations_txvc_unlimit_l2c)s'
# Preprocessing configuration file...
# ['rsync', '-av', '--include=*/', '--include=*.out', '--exclude=*', 'bsc018186@transfer1.bsc.es:/gpfs/scratch/bsc18/bsc018186/VMem/data/txvc_prefetch_eval/BASELINE', './data/txvc_prefetch_eval']
# /home/bsc/bsc018186/.bashrc: line 2: module: command not found
# /home/bsc/bsc018186/.bashrc: line 3: module: command not found
# /home/bsc/bsc018186/.bashrc: line 4: module: command not found
# /home/bsc/bsc018186/.bashrc: line 5: module: command not found
# receiving incremental file list
#
# sent 51 bytes  received 4,228 bytes  2,852.67 bytes/sec
# total size is 2,331,233  speedup is 544.81
# Parsing results for BASELINE...
# Merging results to ./stats/txvc_prefetch_eval/BASELINE/selected_qualcomm_srv_ap_BASELINE.csv
# Parsing completed successfully
# ...

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch.ini --plot --override "EXPERIMENT.simulations = %(simulations_base)s, %(simulations_txvc_unlimit_l1d)s, %(simulations_txvc_unlimit_l2c)s" "PLOTTING.plot_name=txvc_prefetch_eval_unlimit" "PLOTTING.file_type=pdf"
from IPython.display import Image, display
display(Image("./figures/txvc_prefetch_eval/txvc_prefetch_eval_unlimit_ipc_selected_qualcomm_srv_ap.png", 
width=600, height=600))
# Out:
# /home/bscuser/synched_mnt/VMem
# Override applied: EXPERIMENT.simulations='%(simulations_base)s, %(simulations_txvc_unlimit_l1d)s, %(simulations_txvc_unlimit_l2c)s'
# Override applied: PLOTTING.plot_name='txvc_prefetch_eval_unlimit'
# Override applied: PLOTTING.file_type='pdf'
# Preprocessing configuration file...
# ['BASELINE', 'txvc_unlimit_l1d_child_ideal_pf', 'txvc_unlimit_l1d_freq_filter', 'txvc_unlimit_l1d_child_ideal_pf+freq_filter', 'txvc_unlimit_l2c_child_ideal_pf', 'txvc_unlimit_l2c_freq_filter', 'txvc_unlimit_l2c_child_ideal_pf+freq_filter']
# Plotting txvc_prefetch_eval_unlimit for selected_qualcomm_srv_ap
# ['BASELINE', 'txvc_unlimit_l1d_child_ideal_pf', 'txvc_unlimit_l1d_freq_filter', 'txvc_unlimit_l1d_child_ideal_pf+freq_filter', 'txvc_unlimit_l2c_child_ideal_pf', 'txvc_unlimit_l2c_freq_filter', 'txvc_unlimit_l2c_child_ideal_pf+freq_filter']
#                                            tag  IPC_IMPROVEMENT
# ...

# %% [markdown]
# ### TXVC Size Impact

# %%
./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch_vc_size_eval.ini --build --run

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch_vc_size_eval.ini --parse
# Out:
# /home/bscuser/synched_mnt/VMem
# Preprocessing configuration file...
# ['rsync', '-av', '--include=*/', '--include=*.out', '--exclude=*', 'bsc018186@transfer1.bsc.es:/gpfs/scratch/bsc18/bsc018186/VMem/data/txvc_prefetch_eval/BASELINE', './data/txvc_prefetch_eval']
# /home/bsc/bsc018186/.bashrc: line 2: module: command not found
# /home/bsc/bsc018186/.bashrc: line 3: module: command not found
# /home/bsc/bsc018186/.bashrc: line 4: module: command not found
# /home/bsc/bsc018186/.bashrc: line 5: module: command not found
# receiving incremental file list
#
# sent 51 bytes  received 4,228 bytes  2,852.67 bytes/sec
# total size is 2,331,233  speedup is 544.81
# Parsing results for BASELINE...
# Merging results to ./stats/txvc_prefetch_eval/BASELINE/selected_qualcomm_srv_ap_BASELINE.csv
# Parsing completed successfully
# ...

# %%
# %cd /home/bscuser/synched_mnt/VMem
# !./scripts/manage_experiment.py --config exp_conf/txvc_child_prefetch_vc_size_eval.ini --plot
from IPython.display import Image, display
display(Image("./figures/txvc_prefetch_eval/txvc_child_prefetch_vc_size_eval_ipc_selected_qualcomm_srv_ap.png", 
width=600, height=600))
# Out:
# /home/bscuser/synched_mnt/VMem
# Preprocessing configuration file...
# ...
